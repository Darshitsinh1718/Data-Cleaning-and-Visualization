# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_practice_data.csv')

# %%
df
# Out:
#    order_id customer    city product  quantity  price  order_date
# 0       101     Amit   Delhi  Laptop       1.0  60000  2024-01-05
# 1       102     Riya  Mumbai  Mobile       2.0  20000  2024-01-07
# 2       103     Amit   Delhi  Tablet       1.0  15000  2024-01-10
# 3       104    Sohan    Pune  Laptop       1.0  62000  2024-01-15
# 4       105     Riya  Mumbai  Tablet       3.0  14000  2024-01-20
# 5       106     Neha   Delhi  Mobile       NaN  21000  2024-01-22
# 6       107    Sohan    Pune  Laptop       2.0  61000  2024-01-25
# 7       108     Amit     NaN  Mobile       1.0  20500  2024-01-28

# %%
plt.plot(df['order_date'],df['price'])

# %%
df = df.dropna()
sns.barplot(x = 'product',y ='quantity' , data = df)
# Out:
# <Axes: xlabel='product', ylabel='quantity'>

# %%
sns.lineplot(x = 'order_date',y = 'price',data = df)
# Out:
# <Axes: xlabel='order_date', ylabel='price'>

# %%
sns.histplot(df['price'] , bins= 20)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
sns.scatterplot(x='quantity',y='price',data = df)
# Out:
# <Axes: xlabel='quantity', ylabel='price'>

# %%
import pandas as pd

df = pd.read_csv('employee_data_science.csv')

# %%
df.head()
# Out:
#    Age  Salary  Experience Department  Gender  PerformanceScore  WorkHours
# 0   59   40358           2      Sales  Female                 6          7
# 1   49   23267          22         IT  Female                 3         10
# 2   35  102745          17    Finance  Female                 6         10
# 3   63  109588          37         HR  Female                 6          7
# 4   28   58513          34    Finance    Male                 5         11

# %%
sns.scatterplot(x = 'Gender', y = 'Salary', hue="Department",data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
# sns.catplot(x='Gender', y='Salary', col='department', data = df)
# sns.heatmap(df.corr(), annot=True)

# %%
sns.violinplot(y=df["Salary"])
# Out:
# <Axes: ylabel='Salary'>
