# %%
import pandas as pd
import numpy as np

# %%
Enrol_1 = pd.read_csv('Enrolment1.csv')
Enrol_2 = pd.read_csv('Enrolment2.csv')
Enrol_3 = pd.read_csv('Enrolment3.csv')

# %%
Enrol_1.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
Enrol_2.head()
# Out:
#          date           state  district  pincode  age_0_5  age_5_17  \
# 0  26-10-2025  Andhra Pradesh  Nalgonda   508004        0         1
# 1  26-10-2025  Andhra Pradesh  Nalgonda   508238        1         0
# 2  26-10-2025  Andhra Pradesh  Nalgonda   508278        1         0
# 3  26-10-2025  Andhra Pradesh   Nandyal   518432        0         1
# 4  26-10-2025  Andhra Pradesh   Nandyal   518543        1         0
#
#    age_18_greater
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
Enrol_3.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
Enrol_1.shape
# Out:
# (500000, 7)

# %%
Enrol_2.shape
# Out:
# (500000, 7)

# %%
Enrol_3.shape
# Out:
# (6029, 7)

# %%
Enrol_1['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
# ...

# %%
df = pd.concat([Enrol_1,Enrol_2,Enrol_3],axis=0,ignore_index=True)

# %%
df.shape
# Out:
# (1006029, 7)

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df['state']
# Out:
# 0              Meghalaya
# 1              Karnataka
# 2          Uttar Pradesh
# 3          Uttar Pradesh
# 4              Karnataka
#                ...
# 1006024      West Bengal
# 1006025      West Bengal
# 1006026      West Bengal
# 1006027      West Bengal
# 1006028      West Bengal
# Name: state, Length: 1006029, dtype: object

# %%
df['state'] = df['state'].str.strip()

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df['state'].nunique()
# Out:
# 55

# %%
df.isna().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# dtype: int64

# %%
df['state'] = df['state'].str.lower()
df['district'] = df['district'].str.lower()

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      meghalaya  east khasi hills   793121       11        61
# 1  09-03-2025      karnataka   bengaluru urban   560043       14        33
# 2  09-03-2025  uttar pradesh      kanpur nagar   208001       29        82
# 3  09-03-2025  uttar pradesh           aligarh   202133       62        29
# 4  09-03-2025      karnataka   bengaluru urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df['state'] = df['state'].str.replace(r'\bthe\b', '', regex=True).str.strip()

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      meghalaya  east khasi hills   793121       11        61
# 1  09-03-2025      karnataka   bengaluru urban   560043       14        33
# 2  09-03-2025  uttar pradesh      kanpur nagar   208001       29        82
# 3  09-03-2025  uttar pradesh           aligarh   202133       62        29
# 4  09-03-2025      karnataka   bengaluru urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
print(df['state'].unique())
# Out:
# ['meghalaya' 'karnataka' 'uttar pradesh' 'bihar' 'maharashtra' 'haryana'
#  'rajasthan' 'punjab' 'delhi' 'madhya pradesh' 'west bengal' 'assam'
#  'uttarakhand' 'gujarat' 'andhra pradesh' 'tamil nadu' 'chhattisgarh'
#  'jharkhand' 'nagaland' 'manipur' 'telangana' 'tripura' 'mizoram'
#  'jammu and kashmir' 'chandigarh' 'sikkim' 'odisha' 'kerala'
#  'dadra and nagar haveli and daman and diu' 'arunachal pradesh'
#  'himachal pradesh' 'goa' 'ladakh' 'andaman and nicobar islands' 'orissa'
#  'pondicherry' 'puducherry' 'lakshadweep' 'andaman & nicobar islands'
#  'dadra & nagar haveli' 'dadra and nagar haveli' 'daman and diu'
#  'jammu & kashmir' 'west  bengal' '100000' 'daman & diu' 'west bangal'
#  'westbengal']

# %%
df['state'].nunique()
df1 = df

# %%
df[df['state'] == '100000'].shape
# Out:
# (22, 7)

# %%
df['state'].dtype
# Out:
# dtype('O')

# %%
df['state'] = df['state'].replace({
    'west bangal': 'west bengal',
    'westbengal': 'west bengal',
    'west  bengal': 'west bengal'
})

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      meghalaya  east khasi hills   793121       11        61
# 1  09-03-2025      karnataka   bengaluru urban   560043       14        33
# 2  09-03-2025  uttar pradesh      kanpur nagar   208001       29        82
# 3  09-03-2025  uttar pradesh           aligarh   202133       62        29
# 4  09-03-2025      karnataka   bengaluru urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df['state'].nunique()
# Out:
# 45

# %%
df['state'].unique()
# Out:
# array(['meghalaya', 'karnataka', 'uttar pradesh', 'bihar', 'maharashtra',
#        'haryana', 'rajasthan', 'punjab', 'delhi', 'madhya pradesh',
#        'west bengal', 'assam', 'uttarakhand', 'gujarat', 'andhra pradesh',
#        'tamil nadu', 'chhattisgarh', 'jharkhand', 'nagaland', 'manipur',
#        'telangana', 'tripura', 'mizoram', 'jammu and kashmir',
#        'chandigarh', 'sikkim', 'odisha', 'kerala',
#        'dadra and nagar haveli and daman and diu', 'arunachal pradesh',
#        'himachal pradesh', 'goa', 'ladakh', 'andaman and nicobar islands',
#        'orissa', 'pondicherry', 'puducherry', 'lakshadweep',
#        'andaman & nicobar islands', 'dadra & nagar haveli',
#        'dadra and nagar haveli', 'daman and diu', 'jammu & kashmir',
#        '100000', 'daman & diu'], dtype=object)

# %%
df['state'] = df['state'].replace({'orissa' :'odisha'})

# %%
df['state'].nunique()
# Out:
# 44

# %%
df[df['state'] == 'dadra and nagar haveli and daman and diu']
# Out:
#               date                                     state  \
# 1604    01-06-2025  dadra and nagar haveli and daman and diu
# 2895    01-07-2025  dadra and nagar haveli and daman and diu
# 3806    01-09-2025  dadra and nagar haveli and daman and diu
# 27677   02-09-2025  dadra and nagar haveli and daman and diu
# 35283   03-09-2025  dadra and nagar haveli and daman and diu
# ...            ...                                       ...
# 956542  27-12-2025  dadra and nagar haveli and daman and diu
# 984102  29-12-2025  dadra and nagar haveli and daman and diu
# 992518  31-12-2025  dadra and nagar haveli and daman and diu
# 992519  31-12-2025  dadra and nagar haveli and daman and diu
# 996925  31-12-2025  dadra and nagar haveli and daman and diu
#
#                       district  pincode  age_0_5  age_5_17  age_18_greater
# 1604    dadra and nagar haveli   396230      188        49              12
# 2895    dadra and nagar haveli   396230      360        92              15
# ...

# %%
df[df['state'] == 'dadra and nagar haveli']
# Out:
#               date                   state                district  pincode  \
# 11060   01-09-2025  dadra and nagar haveli  dadra and nagar haveli   396235
# 14231   01-09-2025  dadra and nagar haveli  dadra and nagar haveli   396193
# 18324   01-09-2025  dadra and nagar haveli  dadra and nagar haveli   396230
# 23695   02-09-2025  dadra and nagar haveli  dadra and nagar haveli   396230
# 27676   02-09-2025  dadra and nagar haveli  dadra and nagar haveli   396240
# ...            ...                     ...                     ...      ...
# 954061  27-12-2025  dadra and nagar haveli  dadra and nagar haveli   396235
# 974232  29-12-2025  dadra and nagar haveli  dadra and nagar haveli   396235
# 984101  29-12-2025  dadra and nagar haveli  dadra and nagar haveli   396230
# 992517  31-12-2025  dadra and nagar haveli  dadra and nagar haveli   396240
# 996924  31-12-2025  dadra and nagar haveli  dadra and nagar haveli   396230
#
#         age_0_5  age_5_17  age_18_greater
# ...

# %%
df[df['state'] == 'daman and diu']
# Out:
#                date          state district  pincode  age_0_5  age_5_17  \
# 11061    01-09-2025  daman and diu    daman   396210        2         1
# 23696    02-09-2025  daman and diu    daman   396210        1         0
# 42227    03-09-2025  daman and diu    daman   396215        0         1
# 104995   08-09-2025  daman and diu      diu   362570        1         0
# 108247   09-09-2025  daman and diu    daman   396210        1         0
# ...             ...            ...      ...      ...      ...       ...
# 959613   27-12-2025  daman and diu      diu   362540        1         0
# 961472   27-12-2025  daman and diu      diu   362540        1         0
# 974233   29-12-2025  daman and diu      diu   362520        1         0
# 982244   29-12-2025  daman and diu    daman   396215        1         0
# 1003075  31-12-2025  daman and diu    daman   396215        0         1
#
#          age_18_greater
# 11061                 0
# 23696                 0
# 42227                 0
# ...

# %%
df2 = df

# %%
df['state'] = df['state'].replace({ 'daman and diu':'dadra and nagar haveli and daman and diu',
                                    'dadra and nagar haveli': 'dadra and nagar haveli and daman and diu',
                                    'dadra & nagar haveli' : 'dadra and nagar haveli and daman and diu',
                                    'dadra and nagar haveli and daman and diu': 'dadra and nagar haveli and daman and diu',
                                    'daman & diu' : 'dadra and nagar haveli and daman and diu'
                                  })

# %%
df['state'] = df['state'].replace({'jammu & kashmir' : 'jammu and kashmir',
                                   'andaman & nicobar islands' :  'andaman and nicobar islands',
                                   'pondicherry' : 'puducherry'
                                  })

# %%
df['state'].unique()
# Out:
# array(['meghalaya', 'karnataka', 'uttar pradesh', 'bihar', 'maharashtra',
#        'haryana', 'rajasthan', 'punjab', 'delhi', 'madhya pradesh',
#        'west bengal', 'assam', 'uttarakhand', 'gujarat', 'andhra pradesh',
#        'tamil nadu', 'chhattisgarh', 'jharkhand', 'nagaland', 'manipur',
#        'telangana', 'tripura', 'mizoram', 'jammu and kashmir',
#        'chandigarh', 'sikkim', 'odisha', 'kerala',
#        'dadra and nagar haveli and daman and diu', 'arunachal pradesh',
#        'himachal pradesh', 'goa', 'ladakh', 'andaman and nicobar islands',
#        'puducherry', 'lakshadweep', '100000'], dtype=object)

# %%
df = df[df['state'] != '100000']

# %%
df['state'].nunique()
# Out:
# 36

# %%
df['district'].unique()
# Out:
# array(['east khasi hills', 'bengaluru urban', 'kanpur nagar', 'aligarh',
#        'sitamarhi', 'bahraich', 'firozabad', 'purbi champaran',
#        'maharajganj', 'aurangabad', 'ghaziabad', 'faridabad', 'madhubani',
#        'sikar', 'bhagalpur', 'amritsar', 'gurugram',
#        'gautam buddha nagar', 'west delhi', 'bhind', 'gwalior', 'katni',
#        'coochbehar', 'lucknow', 'dinajpur uttar', 'marigaon', 'kokrajhar',
#        'agra', 'haridwar', 'nagaon', 'parbhani', 'west khasi hills',
#        'north west delhi', 'west jaintia hills', 'unnao', 'saharanpur',
#        'dibrugarh', 'udalguri', 'chirang', 'kamrup', 'dhubri', 'jaunpur',
#        'thane', 'dhemaji', 'banas kantha', 'tinsukia', 'spsr nellore',
#        'barpeta', 'sonitpur', 'baksa', 'ludhiana', 'patan', 'kanchipuram',
#        'patna', 'lakhimpur', 'bongaigaon', 'vadodara', 'nainital',
#        'dehradun', 'hojai', 'dohad', 'morbi', 'raipur', 'gorakhpur',
# ...

# %%
df.shape
# Out:
# (1006007, 7)

# %%
df = df.copy()   # now it's independent
df['district'] = df['district'].str.strip()
df['district'] = df['district'].str.replace(r'\s+', ' ', regex=True)
df['district'] = df['district'].str.lower()

# %%
df
# Out:
#                date          state          district  pincode  age_0_5  \
# 0        02-03-2025      meghalaya  east khasi hills   793121       11
# 1        09-03-2025      karnataka   bengaluru urban   560043       14
# 2        09-03-2025  uttar pradesh      kanpur nagar   208001       29
# 3        09-03-2025  uttar pradesh           aligarh   202133       62
# 4        09-03-2025      karnataka   bengaluru urban   560016       14
# ...             ...            ...               ...      ...      ...
# 1006024  31-12-2025    west bengal    west midnapore   721149        2
# 1006025  31-12-2025    west bengal    west midnapore   721150        2
# 1006026  31-12-2025    west bengal    west midnapore   721305        0
# 1006027  31-12-2025    west bengal    west midnapore   721504        1
# 1006028  31-12-2025    west bengal    west midnapore   721517        2
#
#          age_5_17  age_18_greater
# 0              61              37
# 1              33              39
# ...

# %%
df['district'] = df['district'].str.replace(r'[^a-zA-Z0-9\s\-]', '', regex=True)

# %%
df
# Out:
#                date          state          district  pincode  age_0_5  \
# 0        02-03-2025      meghalaya  east khasi hills   793121       11
# 1        09-03-2025      karnataka   bengaluru urban   560043       14
# 2        09-03-2025  uttar pradesh      kanpur nagar   208001       29
# 3        09-03-2025  uttar pradesh           aligarh   202133       62
# 4        09-03-2025      karnataka   bengaluru urban   560016       14
# ...             ...            ...               ...      ...      ...
# 1006024  31-12-2025    west bengal    west midnapore   721149        2
# 1006025  31-12-2025    west bengal    west midnapore   721150        2
# 1006026  31-12-2025    west bengal    west midnapore   721305        0
# 1006027  31-12-2025    west bengal    west midnapore   721504        1
# 1006028  31-12-2025    west bengal    west midnapore   721517        2
#
#          age_5_17  age_18_greater
# 0              61              37
# 1              33              39
# ...

# %%
df['state'].nunique()
# Out:
# 36

# %%
df_guj = df[df['state'] == 'gujarat']

# %%
df_guj['district'].nunique()
# Out:
# 40

# %%
df['state'] = (
    df['state']
    .str.strip()      # remove extra spaces
    .str.lower()      # make everything lowercase first
    .str.title()      # First letter capital
)

# %%
df
# Out:
#                date          state          district  pincode  age_0_5  \
# 0        02-03-2025      Meghalaya  east khasi hills   793121       11
# 1        09-03-2025      Karnataka   bengaluru urban   560043       14
# 2        09-03-2025  Uttar Pradesh      kanpur nagar   208001       29
# 3        09-03-2025  Uttar Pradesh           aligarh   202133       62
# 4        09-03-2025      Karnataka   bengaluru urban   560016       14
# ...             ...            ...               ...      ...      ...
# 1006024  31-12-2025    West Bengal    west midnapore   721149        2
# 1006025  31-12-2025    West Bengal    west midnapore   721150        2
# 1006026  31-12-2025    West Bengal    west midnapore   721305        0
# 1006027  31-12-2025    West Bengal    west midnapore   721504        1
# 1006028  31-12-2025    West Bengal    west midnapore   721517        2
#
#          age_5_17  age_18_greater
# 0              61              37
# 1              33              39
# ...

# %%
df['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu And Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'Dadra And Nagar Haveli And Daman And Diu', 'Arunachal Pradesh',
#        'Himachal Pradesh', 'Goa', 'Ladakh', 'Andaman And Nicobar Islands',
#        'Puducherry', 'Lakshadweep'], dtype=object)

# %%
state_fix = {
    'Jammu And Kashmir': 'Jammu and Kashmir',
    'Andaman And Nicobar Islands' : 'Andaman and Nicobar Islands',
    'Dadra And Nagar Haveli And Daman And Diu' : 'Dadra and Nagar Haveli and Daman and Diu'
}

df['state'] = df['state'].replace(state_fix)

# %%
df['state'].nunique()
# Out:
# 36

# %%
df1 = df

# %%
gujarat_fix = {
    'banas kantha': 'Banaskantha',
    'banaskantha': 'Banaskantha',
    'sabar kantha': 'Sabarkantha',
    'sabarkantha': 'Sabarkantha',
    'panch mahals': 'Panchmahal',
    'panchmahals': 'Panchmahal',
    'surendra nagar': 'Surendranagar',
    'surendranagar': 'Surendranagar',
    'ahmadabad': 'Ahmedabad',
    'ahmedabad': 'Ahmedabad',
    'dohad': 'Dahod',
    'dahod': 'Dahod',
    'the dangs': 'Dang',
    'dang': 'Dang',
    'devbhumi dwarka': 'Devbhoomi Dwarka',
    'mahesana': 'Mehsana',
    'arvalli': 'Aravalli',
    'chhotaudepur': 'Chhota Udaipur',
    'gir somnath': 'Gir Somnath'
}
df['district'] = (
    df['district']
    .str.lower()
    .str.strip()
    .replace(gujarat_fix)
    .str.title()     # capitalize first letter of each word

)

# %%
df_guj = df[df['state'] == 'Gujarat']

# %%
df_guj['district'].unique()
# Out:
# array(['Banaskantha', 'Patan', 'Vadodara', 'Dahod', 'Morbi', 'Kachchh',
#        'Surat', 'Gir Somnath', 'Bhavnagar', 'Gandhinagar', 'Kheda',
#        'Sabarkantha', 'Rajkot', 'Bharuch', 'Chhota Udaipur', 'Panchmahal',
#        'Porbandar', 'Mehsana', 'Devbhoomi Dwarka', 'Tapi', 'Botad',
#        'Junagadh', 'Jamnagar', 'Aravalli', 'Surendranagar', 'Amreli',
#        'Valsad', 'Anand', 'Mahisagar', 'Dang', 'Navsari', 'Ahmedabad',
#        'Narmada'], dtype=object)

# %%
df_megha = df[df['state'] == 'Meghalaya']

# %%
df_megha['district'].unique()
# Out:
# array(['East Khasi Hills', 'West Khasi Hills', 'West Jaintia Hills',
#        'Ri Bhoi', 'West Garo Hills', 'South Garo Hills',
#        'North Garo Hills', 'South West Khasi Hills', 'East Jaintia Hills',
#        'East Garo Hills', 'South West Garo Hills', 'Kamrup',
#        'Eastern West Khasi Hills', 'Jaintia Hills'], dtype=object)

# %%
df_megha
# Out:
#                date      state                district  pincode  age_0_5  \
# 0        02-03-2025  Meghalaya        East Khasi Hills   793121       11
# 46       15-03-2025  Meghalaya        West Khasi Hills   793119       34
# 54       15-03-2025  Meghalaya      West Jaintia Hills   793150       92
# 109      20-03-2025  Meghalaya      West Jaintia Hills   793150       55
# 115      20-03-2025  Meghalaya        West Khasi Hills   793119       20
# ...             ...        ...                     ...      ...      ...
# 1004461  31-12-2025  Meghalaya        South Garo Hills   794103        0
# 1004462  31-12-2025  Meghalaya   South West Garo Hills   794105        0
# 1004463  31-12-2025  Meghalaya  South West Khasi Hills   793114        0
# 1004464  31-12-2025  Meghalaya         West Garo Hills   794002        0
# 1004465  31-12-2025  Meghalaya        West Khasi Hills   793119        0
#
#          age_5_17  age_18_greater
# 0              61              37
# ...
